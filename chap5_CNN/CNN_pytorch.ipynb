# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset = train_data ,batch_size= BATCH_SIZE ,shuffle= True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)
test_x = torch.unsqueeze(test_data.data, dim=1).float()[:500] / 255.
test_y = test_data.targets[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(
                # patch 7 * 7 ; 1  in channels ; 32 out channels ; ; stride is 1
                # padding style is same(that means the convolution opration's input and output have the same size)
                in_channels=1,
                out_channels= 32,
                kernel_size=7,
                stride= 1,
                padding= 3,
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
        )
        self.conv2 = nn.Sequential(
            # line 1 : convolution function, patch 5*5 , 32 in channels ;64 out channels; padding style is same; stride is 1
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, stride=1, padding=2),
            # line 2 : choosing your activation funciont
            nn.ReLU(),
            # line 3 : pooling operation function.
            nn.MaxPool2d(2)
            
        )
        self.out1 = nn.Linear( 7*7*64 , 1024 , bias= True)   # full connection layer one

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)  # flatten the output of coonv2 to (batch_size ,32 * 7 * 7)
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        # 返回 logits；CrossEntropyLoss 内部会做 log-softmax
        return out2


def test(cnn):
    global prediction
    logits = cnn(test_x)
    _,pre_index= torch.max(logits,1)
    pre_index= pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct  = np.sum(prediction == test_y)
    return correct / 500.0


def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate )
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_),Variable(y_)
            output = cnn(x)
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn) ,"=" * 10 )

if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# 100%|██████████| 9.91M/9.91M [00:02<00:00, 3.75MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 244kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 1.99MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 786kB/s]
# ========== 20 ===== ===== test accuracy is  0.38 ==========
# ========== 40 ===== ===== test accuracy is  0.438 ==========
# ========== 60 ===== ===== test accuracy is  0.666 ==========
# ========== 80 ===== ===== test accuracy is  0.72 ==========
# ========== 100 ===== ===== test accuracy is  0.748 ==========
# ========== 120 ===== ===== test accuracy is  0.776 ==========
# ========== 140 ===== ===== test accuracy is  0.782 ==========
# ========== 160 ===== ===== test accuracy is  0.806 ==========
# ========== 180 ===== ===== test accuracy is  0.852 ==========
# ========== 200 ===== ===== test accuracy is  0.828 ==========
# ========== 220 ===== ===== test accuracy is  0.868 ==========
# ========== 240 ===== ===== test accuracy is  0.862 ==========
# ========== 260 ===== ===== test accuracy is  0.878 ==========
# ========== 280 ===== ===== test accuracy is  0.886 ==========
# ========== 300 ===== ===== test accuracy is  0.898 ==========
# ========== 320 ===== ===== test accuracy is  0.902 ==========
# ========== 340 ===== ===== test accuracy is  0.916 ==========
# ========== 360 ===== ===== test accuracy is  0.918 ==========
# ========== 380 ===== ===== test accuracy is  0.914 ==========
# ========== 400 ===== ===== test accuracy is  0.928 ==========
# ========== 420 ===== ===== test accuracy is  0.916 ==========
# ========== 440 ===== ===== test accuracy is  0.926 ==========
# ========== 460 ===== ===== test accuracy is  0.926 ==========
# ========== 480 ===== ===== test accuracy is  0.926 ==========
# ========== 500 ===== ===== test accuracy is  0.928 ==========
# ========== 520 ===== ===== test accuracy is  0.93 ==========
# ========== 540 ===== ===== test accuracy is  0.914 ==========
# ========== 560 ===== ===== test accuracy is  0.934 ==========
# ========== 580 ===== ===== test accuracy is  0.932 ==========
# ========== 600 ===== ===== test accuracy is  0.926 ==========
# ========== 620 ===== ===== test accuracy is  0.942 ==========
# ========== 640 ===== ===== test accuracy is  0.93 ==========
# ========== 660 ===== ===== test accuracy is  0.944 ==========
# ========== 680 ===== ===== test accuracy is  0.944 ==========
# ========== 700 ===== ===== test accuracy is  0.934 ==========
# ========== 720 ===== ===== test accuracy is  0.932 ==========
# ========== 740 ===== ===== test accuracy is  0.958 ==========
# ========== 760 ===== ===== test accuracy is  0.952 ==========
# ========== 780 ===== ===== test accuracy is  0.944 ==========
# ========== 800 ===== ===== test accuracy is  0.948 ==========
# ========== 820 ===== ===== test accuracy is  0.948 ==========
# ========== 840 ===== ===== test accuracy is  0.952 ==========
# ========== 860 ===== ===== test accuracy is  0.942 ==========
# ========== 880 ===== ===== test accuracy is  0.954 ==========
# ========== 900 ===== ===== test accuracy is  0.958 ==========
# ========== 920 ===== ===== test accuracy is  0.952 ==========
# ========== 940 ===== ===== test accuracy is  0.948 ==========
# ========== 960 ===== ===== test accuracy is  0.962 ==========
# ========== 980 ===== ===== test accuracy is  0.966 ==========
# ========== 1000 ===== ===== test accuracy is  0.962 ==========
# ========== 1020 ===== ===== test accuracy is  0.952 ==========
# ========== 1040 ===== ===== test accuracy is  0.976 ==========
# ========== 1060 ===== ===== test accuracy is  0.954 ==========
# ========== 1080 ===== ===== test accuracy is  0.964 ==========
# ========== 1100 ===== ===== test accuracy is  0.966 ==========
# ========== 1120 ===== ===== test accuracy is  0.966 ==========
# ========== 1140 ===== ===== test accuracy is  0.972 ==========
# ========== 1160 ===== ===== test accuracy is  0.954 ==========
# ========== 1180 ===== ===== test accuracy is  0.946 ==========
# ========== 20 ===== ===== test accuracy is  0.968 ==========
# ========== 40 ===== ===== test accuracy is  0.974 ==========
# ========== 60 ===== ===== test accuracy is  0.966 ==========
# ========== 80 ===== ===== test accuracy is  0.978 ==========
# ========== 100 ===== ===== test accuracy is  0.966 ==========
# ========== 120 ===== ===== test accuracy is  0.964 ==========
# ========== 140 ===== ===== test accuracy is  0.972 ==========
# ========== 160 ===== ===== test accuracy is  0.976 ==========
# ========== 180 ===== ===== test accuracy is  0.962 ==========
# ========== 200 ===== ===== test accuracy is  0.968 ==========
# ========== 220 ===== ===== test accuracy is  0.964 ==========
# ========== 240 ===== ===== test accuracy is  0.962 ==========
# ========== 260 ===== ===== test accuracy is  0.972 ==========
# ========== 280 ===== ===== test accuracy is  0.964 ==========
# ========== 300 ===== ===== test accuracy is  0.972 ==========
# ========== 320 ===== ===== test accuracy is  0.974 ==========
# ========== 340 ===== ===== test accuracy is  0.976 ==========
# ========== 360 ===== ===== test accuracy is  0.966 ==========
# ========== 380 ===== ===== test accuracy is  0.974 ==========
# ========== 400 ===== ===== test accuracy is  0.978 ==========
# ========== 420 ===== ===== test accuracy is  0.968 ==========
# ========== 440 ===== ===== test accuracy is  0.962 ==========
# ========== 460 ===== ===== test accuracy is  0.964 ==========
# ========== 480 ===== ===== test accuracy is  0.978 ==========
# ========== 500 ===== ===== test accuracy is  0.968 ==========
# ========== 520 ===== ===== test accuracy is  0.958 ==========
# ========== 540 ===== ===== test accuracy is  0.978 ==========
# ========== 560 ===== ===== test accuracy is  0.974 ==========
# ========== 580 ===== ===== test accuracy is  0.974 ==========
# ========== 600 ===== ===== test accuracy is  0.976 ==========
# ========== 620 ===== ===== test accuracy is  0.984 ==========
# ========== 640 ===== ===== test accuracy is  0.968 ==========
# ========== 660 ===== ===== test accuracy is  0.972 ==========
# ========== 680 ===== ===== test accuracy is  0.972 ==========
# ========== 700 ===== ===== test accuracy is  0.976 ==========
# ========== 720 ===== ===== test accuracy is  0.974 ==========
# ========== 740 ===== ===== test accuracy is  0.972 ==========
# ========== 760 ===== ===== test accuracy is  0.964 ==========
# ========== 780 ===== ===== test accuracy is  0.964 ==========
# ========== 800 ===== ===== test accuracy is  0.976 ==========
# ========== 820 ===== ===== test accuracy is  0.978 ==========
# ========== 840 ===== ===== test accuracy is  0.978 ==========
# ========== 860 ===== ===== test accuracy is  0.972 ==========
# ========== 880 ===== ===== test accuracy is  0.986 ==========
# ========== 900 ===== ===== test accuracy is  0.976 ==========
# ========== 920 ===== ===== test accuracy is  0.976 ==========
# ========== 940 ===== ===== test accuracy is  0.97 ==========
# ========== 960 ===== ===== test accuracy is  0.972 ==========
# ========== 980 ===== ===== test accuracy is  0.982 ==========
# ========== 1000 ===== ===== test accuracy is  0.98 ==========
# ========== 1020 ===== ===== test accuracy is  0.976 ==========
# ========== 1040 ===== ===== test accuracy is  0.98 ==========
# ========== 1060 ===== ===== test accuracy is  0.98 ==========
# ========== 1080 ===== ===== test accuracy is  0.982 ==========
# ========== 1100 ===== ===== test accuracy is  0.978 ==========
# ========== 1120 ===== ===== test accuracy is  0.974 ==========
# ========== 1140 ===== ===== test accuracy is  0.98 ==========
# ========== 1160 ===== ===== test accuracy is  0.978 ==========
# ========== 1180 ===== ===== test accuracy is  0.982 ==========
# ========== 20 ===== ===== test accuracy is  0.978 ==========
# ========== 40 ===== ===== test accuracy is  0.978 ==========
# ========== 60 ===== ===== test accuracy is  0.974 ==========
# ========== 80 ===== ===== test accuracy is  0.982 ==========
# ========== 100 ===== ===== test accuracy is  0.978 ==========
# ========== 120 ===== ===== test accuracy is  0.986 ==========
# ========== 140 ===== ===== test accuracy is  0.978 ==========
# ========== 160 ===== ===== test accuracy is  0.972 ==========
# ========== 180 ===== ===== test accuracy is  0.978 ==========
# ========== 200 ===== ===== test accuracy is  0.976 ==========
# ========== 220 ===== ===== test accuracy is  0.986 ==========
# ========== 240 ===== ===== test accuracy is  0.98 ==========
# ========== 260 ===== ===== test accuracy is  0.978 ==========
# ========== 280 ===== ===== test accuracy is  0.974 ==========
# ========== 300 ===== ===== test accuracy is  0.984 ==========
# ========== 320 ===== ===== test accuracy is  0.984 ==========
# ========== 340 ===== ===== test accuracy is  0.978 ==========
# ========== 360 ===== ===== test accuracy is  0.978 ==========
# ========== 380 ===== ===== test accuracy is  0.978 ==========
# ========== 400 ===== ===== test accuracy is  0.97 ==========
# ========== 420 ===== ===== test accuracy is  0.982 ==========
# ========== 440 ===== ===== test accuracy is  0.984 ==========
# ========== 460 ===== ===== test accuracy is  0.982 ==========
# ========== 480 ===== ===== test accuracy is  0.98 ==========
# ========== 500 ===== ===== test accuracy is  0.984 ==========
# ========== 520 ===== ===== test accuracy is  0.978 ==========
# ========== 540 ===== ===== test accuracy is  0.982 ==========
# ========== 560 ===== ===== test accuracy is  0.972 ==========
# ========== 580 ===== ===== test accuracy is  0.97 ==========
# ========== 600 ===== ===== test accuracy is  0.98 ==========
# ========== 620 ===== ===== test accuracy is  0.98 ==========
# ========== 640 ===== ===== test accuracy is  0.988 ==========
# ========== 660 ===== ===== test accuracy is  0.98 ==========
# ========== 680 ===== ===== test accuracy is  0.976 ==========
# ========== 700 ===== ===== test accuracy is  0.982 ==========
# ========== 720 ===== ===== test accuracy is  0.982 ==========
# ========== 740 ===== ===== test accuracy is  0.978 ==========
# ========== 760 ===== ===== test accuracy is  0.98 ==========
# ========== 780 ===== ===== test accuracy is  0.984 ==========
# ========== 800 ===== ===== test accuracy is  0.98 ==========
# ========== 820 ===== ===== test accuracy is  0.982 ==========
# ========== 840 ===== ===== test accuracy is  0.988 ==========
# ========== 860 ===== ===== test accuracy is  0.984 ==========
# ========== 880 ===== ===== test accuracy is  0.99 ==========
# ========== 900 ===== ===== test accuracy is  0.974 ==========
# ========== 920 ===== ===== test accuracy is  0.99 ==========
# ========== 940 ===== ===== test accuracy is  0.976 ==========
# ========== 960 ===== ===== test accuracy is  0.982 ==========
# ========== 980 ===== ===== test accuracy is  0.976 ==========
# ========== 1000 ===== ===== test accuracy is  0.98 ==========
# ========== 1020 ===== ===== test accuracy is  0.98 ==========
# ========== 1040 ===== ===== test accuracy is  0.978 ==========
# ========== 1060 ===== ===== test accuracy is  0.972 ==========
# ========== 1080 ===== ===== test accuracy is  0.98 ==========
# ========== 1100 ===== ===== test accuracy is  0.986 ==========
# ========== 1120 ===== ===== test accuracy is  0.984 ==========
# ========== 1140 ===== ===== test accuracy is  0.974 ==========
# ========== 1160 ===== ===== test accuracy is  0.98 ==========
# ========== 1180 ===== ===== test accuracy is  0.984 ==========
